# %%
# !pip install -U pypdfium2
# !pip install matplotlib
# !pip install opencv-python
# !pip install pytesseract
# !pip install tqdm
# !pip install spacy
# !pip install nltk
# !pip install paddleocr
# !pip install paddlepaddle
# Out:
# Requirement already satisfied: pypdfium2 in /home/ailab/.local/lib/python3.10/site-packages (4.30.0)
# Requirement already satisfied: matplotlib in /home/ailab/.local/lib/python3.10/site-packages (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ailab/.local/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/ailab/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ailab/.local/lib/python3.10/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ailab/.local/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /home/ailab/.local/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/ailab/.local/lib/python3.10/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/ailab/.local/lib/python3.10/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ailab/.local/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: opencv-python in /home/ailab/.local/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /home/ailab/.local/lib/python3.10/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: pytesseract in /home/ailab/.local/lib/python3.10/site-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in /home/ailab/.local/lib/python3.10/site-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in /home/ailab/.local/lib/python3.10/site-packages (from pytesseract) (10.4.0)
# Requirement already satisfied: tqdm in /home/ailab/.local/lib/python3.10/site-packages (4.66.5)
# Requirement already satisfied: spacy in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ailab/.local/lib/python3.10/site-packages (from spacy) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ailab/.local/lib/python3.10/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/ailab/.local/lib/python3.10/site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/ailab/.local/lib/python3.10/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/ailab/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ailab/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ailab/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ailab/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ailab/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/ailab/.local/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: nltk in /home/ailab/.local/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /home/ailab/.local/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/ailab/.local/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/ailab/.local/lib/python3.10/site-packages (from nltk) (2024.7.24)
# Requirement already satisfied: tqdm in /home/ailab/.local/lib/python3.10/site-packages (from nltk) (4.66.5)
# Requirement already satisfied: paddleocr in /home/ailab/.local/lib/python3.10/site-packages (2.8.1)
# Requirement already satisfied: shapely in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (2.0.5)
# Requirement already satisfied: scikit-image in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (0.24.0)
# Requirement already satisfied: imgaug in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (0.4.0)
# Requirement already satisfied: pyclipper in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (1.3.0.post5)
# Requirement already satisfied: lmdb in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (1.5.1)
# Requirement already satisfied: tqdm in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (4.66.5)
# Requirement already satisfied: numpy<2.0 in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (1.26.4)
# Requirement already satisfied: rapidfuzz in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (3.9.6)
# Requirement already satisfied: opencv-python in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: cython in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (3.0.11)
# Requirement already satisfied: Pillow in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (10.4.0)
# Requirement already satisfied: pyyaml in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from paddleocr) (6.0.2)
# Requirement already satisfied: python-docx in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (1.1.2)
# Requirement already satisfied: beautifulsoup4 in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (4.53.1)
# Requirement already satisfied: fire>=0.3.0 in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (0.6.0)
# Requirement already satisfied: requests in /home/ailab/.local/lib/python3.10/site-packages (from paddleocr) (2.32.3)
# Requirement already satisfied: six in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from fire>=0.3.0->paddleocr) (1.16.0)
# Requirement already satisfied: termcolor in /home/ailab/.local/lib/python3.10/site-packages (from fire>=0.3.0->paddleocr) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in /home/ailab/.local/lib/python3.10/site-packages (from beautifulsoup4->paddleocr) (2.5)
# Requirement already satisfied: scipy in /home/ailab/.local/lib/python3.10/site-packages (from imgaug->paddleocr) (1.14.0)
# Requirement already satisfied: matplotlib in /home/ailab/.local/lib/python3.10/site-packages (from imgaug->paddleocr) (3.9.1.post1)
# Requirement already satisfied: imageio in /home/ailab/.local/lib/python3.10/site-packages (from imgaug->paddleocr) (2.34.2)
# Requirement already satisfied: networkx>=2.8 in /home/ailab/.local/lib/python3.10/site-packages (from scikit-image->paddleocr) (3.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/ailab/.local/lib/python3.10/site-packages (from scikit-image->paddleocr) (2024.7.24)
# Requirement already satisfied: packaging>=21 in /home/ailab/.local/lib/python3.10/site-packages (from scikit-image->paddleocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /home/ailab/.local/lib/python3.10/site-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: lxml>=3.1.0 in /home/ailab/.local/lib/python3.10/site-packages (from python-docx->paddleocr) (5.2.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in /home/ailab/.local/lib/python3.10/site-packages (from python-docx->paddleocr) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ailab/.local/lib/python3.10/site-packages (from requests->paddleocr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ailab/.local/lib/python3.10/site-packages (from requests->paddleocr) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ailab/.local/lib/python3.10/site-packages (from requests->paddleocr) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ailab/.local/lib/python3.10/site-packages (from requests->paddleocr) (2024.7.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ailab/.local/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/ailab/.local/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ailab/.local/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ailab/.local/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr) (2.9.0.post0)
# Requirement already satisfied: paddlepaddle in /home/ailab/.local/lib/python3.10/site-packages (2.6.1)
# Requirement already satisfied: httpx in /home/ailab/.local/lib/python3.10/site-packages (from paddlepaddle) (0.27.0)
# Requirement already satisfied: numpy>=1.13 in /home/ailab/.local/lib/python3.10/site-packages (from paddlepaddle) (1.26.4)
# Requirement already satisfied: Pillow in /home/ailab/.local/lib/python3.10/site-packages (from paddlepaddle) (10.4.0)
# Requirement already satisfied: decorator in /home/ailab/.local/lib/python3.10/site-packages (from paddlepaddle) (5.1.1)
# Requirement already satisfied: astor in /home/ailab/.local/lib/python3.10/site-packages (from paddlepaddle) (0.8.1)
# Requirement already satisfied: opt-einsum==3.3.0 in /home/ailab/.local/lib/python3.10/site-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: protobuf>=3.20.2 in /home/ailab/.local/lib/python3.10/site-packages (from paddlepaddle) (5.27.3)
# Requirement already satisfied: anyio in /home/ailab/.local/lib/python3.10/site-packages (from httpx->paddlepaddle) (4.4.0)
# Requirement already satisfied: certifi in /home/ailab/.local/lib/python3.10/site-packages (from httpx->paddlepaddle) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /home/ailab/.local/lib/python3.10/site-packages (from httpx->paddlepaddle) (1.0.5)
# Requirement already satisfied: idna in /home/ailab/.local/lib/python3.10/site-packages (from httpx->paddlepaddle) (3.7)
# Requirement already satisfied: sniffio in /home/ailab/.local/lib/python3.10/site-packages (from httpx->paddlepaddle) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ailab/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx->paddlepaddle) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ailab/.local/lib/python3.10/site-packages (from anyio->httpx->paddlepaddle) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.1 in /home/ailab/.local/lib/python3.10/site-packages (from anyio->httpx->paddlepaddle) (4.12.2)

# %%
import pypdfium2 as pdfium
import matplotlib.pyplot as plt
from PIL import Image
from io import BytesIO
from pytesseract import image_to_string
import re

# %%
def convert_pdf_to_images(file_path, scale=300/72):

    pdf_file = pdfium.PdfDocument(file_path)
    page_indices = [i for i in range(len(pdf_file))]

    renderer = pdf_file.render(
        pdfium.PdfBitmap.to_pil,
        page_indices = page_indices,
        scale = scale,
    )

    list_final_images = []

    for i, image in zip(page_indices, renderer):

        image_byte_array = BytesIO()
        image.save(image_byte_array, format='jpeg', optimize=True)
        image_byte_array = image_byte_array.getvalue()
        list_final_images.append(dict({i:image_byte_array}))

    return list_final_images

# %%
def display_images(list_dict_final_images):

    all_images = [list(data.values())[0] for data in list_dict_final_images]

    for index, image_bytes in enumerate(all_images):

        image = Image.open(BytesIO(image_bytes))
        figure = plt.figure(figsize = (image.width / 100, image.height / 100))

        plt.title(f"----- Page Number {index+1} -----")
        plt.imshow(image)
        plt.axis("off")
        plt.show()

# %%
# display_images(list_of_images)

# %%
def extract_text_with_pytesseract(list_dict_final_images):

    image_list = [list(data.values())[0] for data in list_dict_final_images]
    image_content = []

    for index, image_bytes in enumerate(image_list):

        image = Image.open(BytesIO(image_bytes))
        raw_text = str(image_to_string(image))
        image_content.append(raw_text)

    return "\n".join(image_content)

# %%
def ocr(pdf_path):
    images = convert_pdf_to_images(pdf_path)
    text = extract_text_with_pytesseract(images)
    return text

# %%
text_org = ocr('MoU_AI_Cardamom.pdf')
text_mod = ocr('MoU_AI_Cardamomv2.pdf')

# %%
text_org = '''The Wonders of Nature

Nature has always been a source of inspiration for humankind. The vast forests, the mighty oceans, and the towering mountains have captivated the imagination of poets, artists, and explorers alike. Every element in nature serves a purpose and contributes to the delicate balance of our ecosystem.

The rustling of leaves in the wind is like a soothing lullaby that can calm the most troubled mind. Many people find solace in nature, and it has been proven to have healing effects on the human spirit.

In the heart of the forest, where sunlight barely reaches the ground, life thrives in a world of its own. The forest floor, covered in moss and fallen leaves, is a testament to the cycle of life and death. Nature teaches us the importance of resilience and adaptation.

However, the rapid pace of human development poses a threat to these natural wonders. Deforestation, pollution, and climate change are some of the challenges that our planet faces. It is crucial for us to take immediate action to preserve the beauty and vitality of our natural world for future generations.

'''

# %%
text_mod = '''
The Wonders of Nature

Nature has always been a source of inspiration for humankind. The vast forests, the mighty oceans, and the towering mountains have captivated the imagination of poets, artists, and explorers alike. Every element in nature serves a purpose and contributes to the delicate balance of our ecosystem.

Many people find solace in nature, and it has been proven to have healing effects on the human spirit. I love spending time with nature.

In the dense heart of the forest, where sunlight barely penetrates, life thrives in a world of its own. The forest floor, covered in moss and fallen leaves, is a testament to the cycle of life and death. Nature teaches us the importance of resilience and adaptation.

Yet, the rapid pace of human development poses a serious threat to these natural wonders. Deforestation, pollution, and climate change are just a few of the challenges that our planet faces. It is crucial for us to take immediate and effective action to preserve the beauty and vitality of our natural world for future generations.
'''

# %%
import difflib
from nltk import sent_tokenize
def split_into_sentences(text):
     # Define a regex pattern to match the tokens you want to remove
    pattern = r'(?<!\S)(\d+(\.\d+)*\.\s*|I[VX]?[I]{0,3}\.\s*)'
    # Remove the tokens from the text
    text = re.sub(pattern, '', text)
    # Strip the text and remove all extra white spaces
    cleaned_text = ' '.join(text.split())
    
    # Tokenize the cleaned text into sentences
    sentences = sent_tokenize(cleaned_text)
    return sentences
    
def compare_sentences(text1, text2, lower_threshold=0.5, upper_threshold=0.98):
    """
    Compares sentences from two texts and returns a list of results indicating whether they match,
    are modified, added, or deleted.
    Uses similarity thresholds to determine matches and modifications.
    """
    sentences1 = split_into_sentences(text1)
    sentences2 = split_into_sentences(text2)

    results = []
    matched_indices1 = set()
    matched_indices2 = set()

    # Compare each sentence in text2 against all sentences in text1
    for idx2, sent2 in enumerate(sentences2):
        best_match = None
        best_similarity = 0.0
        best_idx1 = None

        for idx1, sent1 in enumerate(sentences1):
            if idx1 in matched_indices1:
                continue

            similarity = difflib.SequenceMatcher(None, sent1, sent2).ratio()

            if similarity > best_similarity:
                best_similarity = similarity
                best_match = (idx2, "Match" if similarity >= upper_threshold else "Modified", similarity, sent1, sent2)
                best_idx1 = idx1

        if best_similarity >= lower_threshold:
            results.append(best_match)
            matched_indices1.add(best_idx1)
            matched_indices2.add(idx2)
        else:
            results.append((idx2, "Added", 0.0, None, sent2))
            matched_indices2.add(idx2)

    # Check for any sentences in text1 not found in text2
    for idx1, sent1 in enumerate(sentences1):
        if idx1 not in matched_indices1:
            results.append((None, "Deleted", 0.0, sent1, None))

    return results

results = compare_sentences(text_org, text_mod)

for index, result, similarity, sent1, sent2 in results:
    print(f"Sentence {index + 1 if index is not None else 'N/A'}: {result} (Similarity: {similarity:.2f})")
    print(f"Original: {sent1}")
    print(f"Modified: {sent2}")
    print("-" * 50)


results = compare_sentences(text_org, text_mod)

for index, result, similarity, sent1, sent2 in results:
    print(f"Sentence {index + 1 if index is not None else 'N/A'}: {result} (Similarity: {similarity:.2f})")
    print(f"Original: {sent1}")
    print(f"Modified: {sent2}")
    print("-" * 50)
# Out:
# Sentence 1: Match (Similarity: 1.00)
# Original: The Wonders of Nature Nature has always been a source of inspiration for humankind.
# Modified: The Wonders of Nature Nature has always been a source of inspiration for humankind.
# --------------------------------------------------
# Sentence 2: Match (Similarity: 1.00)
# Original: The vast forests, the mighty oceans, and the towering mountains have captivated the imagination of poets, artists, and explorers alike.
# Modified: The vast forests, the mighty oceans, and the towering mountains have captivated the imagination of poets, artists, and explorers alike.
# --------------------------------------------------
# Sentence 3: Match (Similarity: 1.00)
# Original: Every element in nature serves a purpose and contributes to the delicate balance of our ecosystem.
# Modified: Every element in nature serves a purpose and contributes to the delicate balance of our ecosystem.
# --------------------------------------------------
# Sentence 4: Match (Similarity: 1.00)
# Original: The rustling of leaves in the wind is like a soothing lullaby that can calm the most troubled mind.
# Modified: The rustling of leaves in the wind is like a soothing lullaby that can calm the most troubled mind.
# --------------------------------------------------
# Sentence 5: Match (Similarity: 1.00)
# Original: Many people find solace in nature, and it has been proven to have healing effects on the human spirit.
# Modified: Many people find solace in nature, and it has been proven to have healing effects on the human spirit.
# --------------------------------------------------
# Sentence 6: Modified (Similarity: 0.88)
# Original: In the heart of the forest, where sunlight barely reaches the ground, life thrives in a world of its own.
# Modified: In the dense heart of the forest, where sunlight barely penetrates, life thrives in a world of its own.
# --------------------------------------------------
# Sentence 7: Match (Similarity: 1.00)
# Original: The forest floor, covered in moss and fallen leaves, is a testament to the cycle of life and death.
# Modified: The forest floor, covered in moss and fallen leaves, is a testament to the cycle of life and death.
# --------------------------------------------------
# Sentence 8: Match (Similarity: 1.00)
# Original: Nature teaches us the importance of resilience and adaptation.
# Modified: Nature teaches us the importance of resilience and adaptation.
# --------------------------------------------------
# Sentence 9: Modified (Similarity: 0.91)
# Original: However, the rapid pace of human development poses a threat to these natural wonders.
# Modified: Yet, the rapid pace of human development poses a serious threat to these natural wonders.
# --------------------------------------------------
# Sentence 10: Modified (Similarity: 0.95)
# Original: Deforestation, pollution, and climate change are some of the challenges that our planet faces.
# Modified: Deforestation, pollution, and climate change are just a few of the challenges that our planet faces.
# --------------------------------------------------
# Sentence 11: Modified (Similarity: 0.95)
# Original: It is crucial for us to take immediate action to preserve the beauty and vitality of our natural world for future generations.
# Modified: It is crucial for us to take immediate and effective action to preserve the beauty and vitality of our natural world for future generations.
# --------------------------------------------------

# %%
# !pip install reportlab
# Out:
# Collecting reportlab
#   Downloading reportlab-4.2.2-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: pillow>=9.0.0 in /home/ailab/.local/lib/python3.10/site-packages (from reportlab) (10.4.0)
# Requirement already satisfied: chardet in /home/ailab/anaconda3/envs/pdf_comp/lib/python3.10/site-packages (from reportlab) (5.2.0)
# Downloading reportlab-4.2.2-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 4.2 MB/s eta 0:00:0000:0100:010m
# Installing collected packages: reportlab
# Successfully installed reportlab-4.2.2

# %%
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer

def create_pdf(results, filename="comparison_report.pdf"):
    doc = SimpleDocTemplate(filename, pagesize=letter)
    styles = getSampleStyleSheet()
    story = []
    
    for index, result, similarity, para1, para2 in results:
        if result in ["Modified", "Deleted", "Added"]:
            if result == "Modified":
                story.append(Paragraph(f"<b>Sentence {index + 1 if index is not None else 'N/A'}: {result} (Similarity: {similarity:.2f})</b>", styles["Normal"]))
                story.append(Paragraph(f"<b>Original:</b> {para1}", styles["Normal"]))
                story.append(Paragraph(f"<b>Modified:</b> {para2}", styles["Normal"]))
            elif result == "Deleted":
                story.append(Paragraph(f"<b>Sentence {index + 1 if index is not None else 'N/A'}: {result}</b>", styles["Normal"]))
                story.append(Paragraph(f"<b>Original:</b> {para1}", styles["Normal"]))
            elif result == "Added":
                story.append(Paragraph(f"<b>Sentence {index + 1 if index is not None else 'N/A'}: {result}</b>", styles["Normal"]))
                story.append(Paragraph(f"<b>Modified:</b> {para2}", styles["Normal"]))
            story.append(Spacer(1, 12))
            story.append(Spacer(1, 12))

    doc.build(story)

# %%
create_pdf(results, "comparison_report.pdf")
